# %%
import matplotlib.pyplot as plt
import importlib
import plotter
import numpy as np

# %%
importlib.reload(plotter)
# Out:
# <module 'plotter' from '/Users/mac/Desktop/syt/Deep-Learning/Projects-M/Plotting-agent-DEMO/ChartDialog/models/seq2seq/plotter.py'>

# %%
data, params = plotter.sample_one_hard('histogram')
params
# Out:
# {'plot_type': 'histogram',
#  'line_color': None,
#  'line_style': None,
#  'line_width': None,
#  'marker_type': None,
#  'marker_size': None,
#  'marker_edge_width': None,
#  'marker_edge_color': None,
#  'marker_face_color': None,
#  'marker_interval': None,
#  'number_of_bins': 8,
#  'bar_relative_width': 0.8,
#  'bar_edge_width': 'thin',
#  'bar_edge_color': 'red',
#  'bar_face_color': 'gray',
#  'color_map': None,
#  'bar_orientation': None,
#  'bar_width': None,
#  'bar_height': None,
#  'contour_plot_type': None,
#  'number_of_levels': None,
#  'density': None,
#  'arrow_size': None,
#  'arrow_style': None,
#  'surface_color': None,
#  'explode': None,
#  'precision_digits': None,
#  'percentage_distance_from_center': None,
#  'label_distance_from_center': None,
#  'radius': None,
#  'section_edge_width': None,
#  'section_edge_color': None,
#  'show_error_bar': None,
#  'error_bar_cap_size': None,
#  'error_bar_cap_thickness': None,
#  'error_bar_color': None,
# ...

# %%
data
# Out:
# {'x': array([163.86517497, 171.71555153, 170.84625401, 163.29732462,
#         193.23706108, 161.34919541, 180.4662409 , 154.37715292,
#         172.51453659, 159.13831588, 212.32041858, 163.4398005 ,
#         150.78277779, 159.55718741, 175.03956797, 158.95030983,
#         161.68467285, 169.19061379, 152.31985913, 154.34193244,
#         212.55476206, 173.74490094, 161.98783648, 169.06441639,
#         165.70694122, 156.74835937, 183.4405517 , 160.80834278,
#         166.87701353, 182.08069203, 189.35791192, 202.61009045,
#         161.80926156, 153.21965799, 174.83478577, 153.0003164 ,
#         154.61302642, 140.        , 145.        , 150.        ,
#         155.        , 160.        , 165.        , 170.        ,
#         175.        , 180.        , 185.        , 190.        ,
#         195.        , 200.        ]),
#  'hist_range': (140, 200),
#  'c_type': 'histogram'}

# %%
kwargs = plotter.plotter_kwargs_unnaturalize(**params)
plotter.plotter(**data, **kwargs)

# %%
# data['x'] = np.array(['2020-06-{:02}'.format(i+1) for i in range(11)])
# kwargs['bar_orientation'] = 'vertical'
# kwargs['x_axis_position'] = 'bottom'
kwargs['plot_title'] = 'Experiment histogram'
kwargs['x_axis_label'] = 'Reaction Time (s)'
kwargs['y_axis_label'] = 'Energy (kJ)'
data['hist_range'] = None
plotter.plotter(**data, **kwargs)
